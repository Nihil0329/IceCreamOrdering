# %%
class Icecream(object):
    def __init__(self, name, price):
        self.name = name
        self.price = price
    
    def getboth(self):
        return self.name,self.price

    def getcost(self):
        return self.price

def validateinp(inp,length):
  if(inp>length):
    return 1

def typice(typ,fla,quantity):
  bill=(quantity//100)*(list1[typ-1]+list2[fla-1])
  return bill

def typetop(bill,typetopping):
  amount=bill+list3[typetopping-1]
  return amount

def toprint(menu):
  for i in zip(*menu):
    print(*i)
    
flavours= ["chocolate","vanilla","strawberry"]
flavours_costs = [30,40,50]

types= ["cup","stick","cone"]
types_costs = [20,40,60]

toppings=["Oreo crumbles","Cherries","Chocolate chips","Fruity-Fruity"]
toppings_costs=[20,35,60,10]

obj1=Icecream(types,types_costs)
obj2=Icecream(flavours,flavours_costs)
obj3=Icecream(toppings,toppings_costs)

print("----------MENU---------") 
menu_items1=obj1.getboth()
menu_items2=obj2.getboth()
menu_items3=obj3.getboth()

print("TYPES")
toprint(menu_items1)
print("\nFLAVOUR")
toprint(menu_items2)

print("--------PLACE ORDER--------")
print("\nENTER TYPE OF ICECREAM\n 1.CUP\n 2.STICK\n 3.CONE")
while(1):
  ice_type=int(input())
  if(validateinp(ice_type,len(menu_items1))):
    print("Enter valid input")
  else:
    break
  
print("\nENTER FLAVOR\n 1.CHOCOLATE\n 2.VANILLA\n 3.STRAWBERRY")
while(1):
  ice_flavour=int(input())
  if(validateinp(ice_flavour,len(menu_items2))):
    print("Enter valid input")
  else:
    break

print("--------ORDER BILL---------")
list1=obj1.getcost()
list2=obj2.getcost()
list3=obj3.getcost()

print("ENTER QUANTITY IN GRAMS")
quantity=int(input())
print("TOTAL AMOUNT:")

bill=typice(ice_type,ice_flavour,quantity)
print(bill)

if(ice_flavour==1):
  print("\n---------TOPPINGS---------\n")
  k=1
  for i in zip(*menu_items3):
    print(k,'.',*i)
    k+=1
while(1):
  typetopping=int(input())
  if(validateinp(typetopping,len(menu_items3))):
    print("Enter valid input")
  else:
    break
    amount=typetop(bill,typetopping)

print("Total bill:",amount)
